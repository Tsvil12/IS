# %% [markdown]
# ### Лабораторная 2 Цвиль Павел
# ---

# %% [markdown]
# # Задание №1 – «Делаем срезы»
# Условие: Дана строка. Вывести:
#
# Третий символ
#
# Предпоследний символ
#
# Первые пять символов
#
# Всю строку кроме последних двух символов
#
# Символы с чётными индексами (0,2,4...)
#
# Символы с нечётными индексами (1,3,5...)
#
# Строку в обратном порядке
#
# Символы через один в обратном порядке, начиная с последнего
#
# Длину строки

# %%
s = input("Введите строку: ")

print(s[2])
print(s[-2])
print(s[:5])
print(s[:-2])
print(s[::2])
print(s[1::2])
print(s[::-1])
print(s[::-2])
print(len(s))
# Out:
# к
# й
# сикс
# сикс севен плейбой карти ша
# ск ее лйо ат а
# иссвнпебйкришй
#  йаш итрак йобйелп невес скис
#  а та ойл ее кс
# 29

# %% [markdown]
# # 2 Задача «Две половинки»
# Условие
#
# Дана строка. Разрежьте ее на две равные части (если длина строки — четная, а если длина строки нечетная, то длина первой части должна быть на один символ больше). Переставьте эти две части местами, результат запишите в новую строку и выведите на экран.
#
# При решении этой задачи не стоит пользоваться инструкцией if.

# %%
s = input("Введите строку: ")

mid = (len(s) + 1) // 2

first = s[:mid]
second = s[mid:]

result = second + first

print(result)
# Out:
# н 67 6 7сикс севе

# %% [markdown]
# # № 3
# Задача «Обращение фрагмента»
# Условие
#
# Дана строка, в которой буква h встречается как минимум два раза. Разверните последовательность символов, заключенную между первым и последним появлением буквы h, в противоположном порядке.

# %%
s = input("Введите строку: ")

first_h = s.find('h')
last_h = s.rfind('h')

middle = s[first_h + 1:last_h]
reversed_middle = middle[::-1]

result = s[:first_h + 1] + reversed_middle + s[last_h:]

print(result)
# Out:
# xdxdhfedcbahxd

# %% [markdown]
# # № 4
# Задача «Первое и последнее вхождения»
# Условие
#
# Дана строка. Если в этой строке буква f встречается только один раз, выведите её индекс. Если она встречается два и более раз, выведите индекс её первого и последнего появления. Если буква f в данной строке не встречается, ничего не выводите.
#
# При решении этой задачи не стоит использовать циклы.

# %%
s = input("Введите строку: ")

first = s.find('f')
last = s.rfind('f')

if first == -1:
    pass
elif first == last:
    print(first)
else:
    print(first, last)
# Out:
# 4 9

# %% [markdown]
# # № 5
# Задача
# Пользователь (или несколько пользователей за одним компьютером) вводит слова. Начиная со второго введённого слова, программа проверяет, совпадает ли первая буква свежевведённого слова с последней буквой предыдущего. Если да, то программа работает дальше (считывает очередное слово). Если нет — выводит последнее на этот момент введённое слово и завершает работу.

# %%
a = input()

while True:
    word = input()
    if word[0] != a[-1]:
        print(word)
        break
    a = word
# Out:
# конец

# %% [markdown]
# # № 6
# Задача
# Выведите слово так, как будто ему что-то мешает произноситься. Каждую букву нужно вывести столько раз, каков ее номер в строке.

# %%
s = input()

for i in range(len(s)):
    print(s[i] * (i + 1), end='')
# Out:
# шккооолллльььььннннннииииииикккккккк

# %% [markdown]
# # № 7
# Задача
# Изобразите извилистый спуск улитки по стене по заданной траектории. Вводится одна строка. Начальный символ этой строки — символ рисования пути улитки. Далее следует последовательность символов "<", ">" и "V", которые означают движение улитки, соответственно, влево, вправо и вниз. Гарантируется, что по любой горизонтали движение происходит только в одну сторону (иными словами, между идущими в любом порядке "<" и ">" всегда есть хотя бы один "V") и что путь не пройдёт левее начального положения. Выводятся несколько строк, состоящих из символов рисования пути и пробелов. Верхний левый угол соответствует начальному положению улитки. Каждый последующий символ входной строки означает, что нужно дорисовать символ рисования пути левее, правее или ниже предыдущего. Пробелы используются для отступов.

# %%
def draw_snail_path(path):
    size = len(path) * 2
    grid = [[' ' for _ in range(size)] for _ in range(size)]

    x, y = 0, 0
    grid[y][x] = path[0]

    for i in range(1, len(path)):
        if path[i] == '<':
            x -= 1
        elif path[i] == '>':
            x += 1
        elif path[i] == 'V':
            y += 1

        grid[y][x] = path[i]

    for row in grid:
        print(' '.join(row).rstrip())

input_path = "<<>VV>><<V"

draw_snail_path(input_path)
# Out:
# >                                     <
# V
# < < >
# V

# %% [markdown]
# # № 8
# Задача
# Давайте попробуем на самом деле растянуть слова, как будто они резиновые. Возьмём за середину и будем тянуть. Если в слове нечётное количество букв, на верхушке окажется одна буква. А вот если чётное, то тянуть будем за две средние буквы, они и окажутся наверху. Напишите программу, которая покажет, как будет выглядеть растянутое слово. При решении задачи можно использовать только циклы и операции над строками и числами.

# %%
word = input()
n = len(word)

if n % 2 == 1:
    mid = n // 2
    left = word[:mid][::-1]
    right = word[mid+1:]
    middle = word[mid]
    
    for i in range(len(left)):
        print(' ' * (len(left) - i) + left[i] + ' ' * (2 * i) + middle + ' ' * (2 * i) + right[i])
else:
    mid = n // 2
    left = word[:mid-1][::-1]
    right = word[mid+1:]
    middle = word[mid-1:mid+1]
    
    for i in range(len(left)):
        print(' ' * (len(left) - i) + left[i] + ' ' * (2 * i) + middle + ' ' * (2 * i) + right[i])
# Out:
#    ейб
#   л  й  о
#  п    й    й

# %% [markdown]
# # № 9
# Задача «Больше предыдущего»
# Условие
#
# Дан список чисел. Выведите все элементы списка, которые больше предыдущего элемента.

# %%
a = list(map(int, input().split()))
print("Спискок: ", a)
for i in range(1, len(a)):
    if a[i] > a[i - 1]:
        print(a[i], end=' ')
# Out:
# Спискок:  [61, 71, 81, 72]
# 71 81

# %% [markdown]
# # № 10
# Задача «Соседи одного знака»
# Условие
#
# Дан список чисел. Если в нем есть два соседних элемента одного знака, выведите эти числа. Если соседних элементов одного знака нет — не выводите ничего. Если таких пар соседей несколько — выведите первую пару.

# %%
a = list(map(int, input().split()))
print("Спискок: ", a)
for i in range(len(a) - 1):
    if a[i] * a[i + 1] > 0:
        print(a[i], a[i + 1])
        break
# Out:
# Спискок:  [67, -67, -41, 45, -87, -91, -5, 2, 8, 5]
# -67 -41

# %% [markdown]
# # № 11
# Задача «Переставить соседние»
# Условие
#
# Переставьте соседние элементы списка (A[0] с A[1], A[2] с A[3] и т. д.). Если элементов нечетное число, то последний элемент остается на своем месте.

# %%
a = list(map(int, input().split()))
print("Спискок: ", a)
for i in range(0, len(a) - 1, 2):
    a[i], a[i + 1] = a[i + 1], a[i]

print(' '.join(map(str, a)))
# Out:
# Спискок:  [6, 7, 1, 9, 82, 5, 2]
# 7 6 9 1 5 82 2

# %% [markdown]
# # № 12
# Задача «Уникальные элементы»
# Условие
#
# Дан список. Выведите те его элементы, которые встречаются в списке только один раз. Элементы нужно выводить в том порядке, в котором они встречаются в списке.

# %%
a = list(map(int, input().split()))
print("Спискок: ", a)
for i in range(len(a)):
    if a.count(a[i]) == 1:
        print(a[i], end=' ')
# Out:
# Спискок:  [5, 2, 3, 4, 4, 1, 2, 3, 6]
# 5 1 6

# %% [markdown]
# # № 13
# Задача
# Напишите программу, которая составляет новое предложение по номерам слов из исходной строки. Предложение должно начинаться с большой буквы. Гарантируется, что в исходной строке только одна заглавная буква (в начале предложения). Нумерация слов начинается с единицы.

# %%
s = input().split()
indices = list(map(int, input().split()))

result_words = [s[i - 1].lower() for i in indices]
result_words[0] = result_words[0].capitalize()

print(' '.join(result_words))
# Out:
# Привет я паша

# %% [markdown]
# # № 14
# Задача «Ферзи»
# Условие
#
# Известно, что на доске 8×8 можно расставить 8 ферзей так, чтобы они не били друг друга. Вам дана расстановка 8 ферзей на доске: определите, есть ли среди них пара бьющих друг друга.
#
# Программа получает на вход восемь пар чисел, каждое число от 1 до 8 — координаты 8 ферзей. Если ферзи не бьют друг друга, выведите слово NO, иначе выведите YES

# %%
coords = []
for _ in range(8):
    x, y = map(int, input().split())
    coords.append((x, y))

attack = False

for i in range(8):
    for j in range(i + 1, 8):
        x1, y1 = coords[i]
        x2, y2 = coords[j]
        if x1 == x2 or y1 == y2 or abs(x1 - x2) == abs(y1 - y2):
            attack = True
            break
    if attack:
        break

print('ДА' if attack else 'НЕТ')
# Out:
# ДА

# %% [markdown]
# # № 15
# Задача
# Окунёмся в суровый и беспощадный мир очереди на приём к врачу в поликлинике. Напишите программу-медсестру, которая поможет врачу определить, кто следующий проходит к нему в кабинет.
#
# Изначально в очереди никого нет. Далее в каком-то порядке происходят события трёх типов:
#
# фраза «Кто последний? Я - <фамилия>.» означает, что пришёл новый пациент и встал в конец очереди;
#
# фраза «Я только спросить! Я - <фамилия>.» означает, что пришёл новый пациент и встал в начало очереди;
#
# фраза «Следующий!» означает, что доктор готов принять первого пациента в очереди. В последнем случае нужно вывести «Заходит <фамилия>!» или «В очереди никого нет.»

# %%
from collections import deque

queue = deque()

while True:
    try:
        s = input()
    except EOFError:
        break
    
    if s.startswith('Кто последний?'):
        name = s.split(' - ')[1].strip('.')
        queue.append(name)
    
    elif s.startswith('Я только спросить!'):
        name = s.split(' - ')[1].strip('.')
        queue.appendleft(name)
    
    elif s == 'Следующий!':
        if queue:
            print(f'Заходит {queue.popleft()}!')
        else:
            print('В очереди никого нет.')
# Out:
# Заходит В!
# Заходит А!
# Заходит Б!
# В очереди никого нет.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       4
#       5 while True:
#       6     try:
#       7         s = input()
# ----> 8     except EOFError:
#       9         break
#      10
#      11     if s.startswith('Кто последний?'):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# ...
